# %%
# ====================================================================================================================
# Single Linked List Implementation
# ====================================================================================================================


# 1. Create Node Class
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None  # Pointer to the next node

# 2. Create LinkedList Class
class LinkedList:
    def __init__(self):
        self.head = None  # Start of the list

    # Create Append Method
    def append(self, value):
        new_node = Node(value)
        
        # If the list is empty, make the new node the head
        if not self.head:
            self.head = new_node
            return
        
        # Otherwise, traverse to the end of the list
        current = self.head
        while current.next:
            current = current.next
        
        # Link the last node to the new node
        current.next = new_node

    # Fixed Display Method (Indentation corrected)
    def display(self):
        current = self.head
        elements = []
        while current:
            elements.append(str(current.value))
            current = current.next
        print(" -> ".join(elements) + " -> None")

    # Function to count nodes
def count_nodes(head):
    count = 0
    current = head
    while current:
        count += 1
        current = current.next
    return count


node1 = Node(10)
node2 = Node(20)
node3 = Node(30)

def prepend(self, value):
        """Inserts a new node at the beginning of the list."""
        # 1 & 2. Create a new node with the given value
        new_node = Node(value)

# Execute and print result
total_nodes = count_nodes(node1)

def remove_by_value(self, value):
    # If the list is empty, do nothing
    if self.head is None:
        return

    # If the head is the node to remove, update the head
    if self.head.value == value:
        self.head = self.head.next
        return

    # Walk through the list and skip the node with the matching value
    current = self.head
    while current.next is not None:
        if current.next.value == value:
            # Skip the node by pointing current.next to the one after it
            current.next = current.next.next
            return
        current = current.next


# --- Execution ---
myList = LinkedList()
myList.append(10)
myList.append(20)
myList.append(30)

Print("Initial list (before append)")
myList.print
myList.prepend(50)
myList

my_list.display()
print("Node count: ")("my_list")
# Out:
# There are 1 nodes in the list.
# 10 -> 20 -> 30 -> None
